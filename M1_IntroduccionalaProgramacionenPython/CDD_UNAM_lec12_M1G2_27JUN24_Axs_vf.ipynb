# %%
#pip install sidetable

# %%
import pandas as pd, numpy as np

# %%
df = pd.read_csv('empleados_3.csv', parse_dates = ['fh_ant'])
df2 = df
df2.head()
# Out:
#      nombre  es_directivo genero     fh_ant   pct bono  \
# 0       Ana         False    NaN 1997-04-24   7.719971
# 1    Mónica         False      F 2012-06-15  14.231140
# 2       Ana         False      F 1985-12-10  10.035779
# 3  Bernardo         False      M 2017-11-26   8.657518
# 4     Laura          True      F 2001-03-16  12.073975
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736

# %% [markdown]
# ### Borrar columnas de DF

# %%
df2.pop('nombre') # es permanente, no requiere inplace:
df2.head()
# Out:
#    es_directivo genero     fh_ant   pct bono                     area  salario
# 0         False    NaN 1997-04-24   7.719971                 sistemas  2133821
# 1         False      F 2012-06-15  14.231140    corporate investments   339196
# 2         False      F 1985-12-10  10.035779                  compras  1886316
# 3         False      M 2017-11-26   8.657518                  riesgos  3232929
# 4          True      F 2001-03-16  12.073975  valoración y desarrollo  2378736

# %%
genero = df2.pop('genero')
genero # es permanente y devuelve lo que borró.
# Out:
# 0      NaN
# 1        F
# 2        F
# 3        M
# 4        F
#       ...
# 617      F
# 618      F
# 619      M
# 620      F
# 621      F
# Name: genero, Length: 622, dtype: object

# %%
df2.head()
# Out:
#    es_directivo     fh_ant   pct bono                     area  salario
# 0         False 1997-04-24   7.719971                 sistemas  2133821
# 1         False 2012-06-15  14.231140    corporate investments   339196
# 2         False 1985-12-10  10.035779                  compras  1886316
# 3         False 2017-11-26   8.657518                  riesgos  3232929
# 4          True 2001-03-16  12.073975  valoración y desarrollo  2378736

# %%
# otra forma:
del df2['salario']
df2 #el cambio es permanente
# Out:
#      es_directivo     fh_ant   pct bono                     area
# 0           False 1997-04-24   7.719971                 sistemas
# 1           False 2012-06-15  14.231140    corporate investments
# 2           False 1985-12-10  10.035779                  compras
# 3           False 2017-11-26   8.657518                  riesgos
# 4            True 2001-03-16  12.073975  valoración y desarrollo
# ..            ...        ...        ...                      ...
# 617         False 1981-05-30  10.681927          mesa de control
# 618          True 2002-04-03   9.133581    corporate investments
# 619         False 2011-05-09  14.143523                staff red
# 620          True 2015-02-21   6.100000            reclutamiento
# 621          True 2017-03-15  10.000000                 staff DG
#
# [622 rows x 4 columns]

# %% [markdown]
# ## Método drop para filas y columnas

# %%
df = pd.read_csv('empleados_3.csv', parse_dates = ['fh_ant'])
df2 = df
df2.head()
# Out:
#      nombre  es_directivo genero     fh_ant   pct bono  \
# 0       Ana         False    NaN 1997-04-24   7.719971
# 1    Mónica         False      F 2012-06-15  14.231140
# 2       Ana         False      F 1985-12-10  10.035779
# 3  Bernardo         False      M 2017-11-26   8.657518
# 4     Laura          True      F 2001-03-16  12.073975
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736

# %%
df2.drop(1) #quitando el renglón con índice 1
#drop() NO ES PERMANENTE, A MENOS que inplace = True
# Out:
#        nombre  es_directivo genero     fh_ant   pct bono  \
# 0         Ana         False    NaN 1997-04-24   7.719971
# 2         Ana         False      F 1985-12-10  10.035779
# 3    Bernardo         False      M 2017-11-26   8.657518
# 4       Laura          True      F 2001-03-16  12.073975
# 5      Daniel          True      M 2013-12-20  19.613251
# ..        ...           ...    ...        ...        ...
# 617     Edith         False      F 1981-05-30  10.681927
# 618      Olga          True      F 2002-04-03   9.133581
# 619  Jerónimo         False      M 2011-05-09  14.143523
# 620     Areli          True      F 2015-02-21   6.100000
# 621      Beto          True      F 2017-03-15  10.000000
#
#                         area  salario
# 0                   sistemas  2133821
# 2                    compras  1886316
# 3                    riesgos  3232929
# 4    valoración y desarrollo  2378736
# 5                   staff DG  4364527
# ..                       ...      ...
# ...

# %%
df2.head()
# Out:
#      nombre  es_directivo genero     fh_ant   pct bono  \
# 0       Ana         False    NaN 1997-04-24   7.719971
# 1    Mónica         False      F 2012-06-15  14.231140
# 2       Ana         False      F 1985-12-10  10.035779
# 3  Bernardo         False      M 2017-11-26   8.657518
# 4     Laura          True      F 2001-03-16  12.073975
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736

# %%
df2.drop([1,3,5])
# Out:
#        nombre  es_directivo genero     fh_ant   pct bono  \
# 0         Ana         False    NaN 1997-04-24   7.719971
# 2         Ana         False      F 1985-12-10  10.035779
# 4       Laura          True      F 2001-03-16  12.073975
# 6        René          True      M 2002-04-12   9.363798
# 7     Ignacio         False      M 1987-09-11  17.230757
# ..        ...           ...    ...        ...        ...
# 617     Edith         False      F 1981-05-30  10.681927
# 618      Olga          True      F 2002-04-03   9.133581
# 619  Jerónimo         False      M 2011-05-09  14.143523
# 620     Areli          True      F 2015-02-21   6.100000
# 621      Beto          True      F 2017-03-15  10.000000
#
#                         area  salario
# 0                   sistemas  2133821
# 2                    compras  1886316
# 4    valoración y desarrollo  2378736
# 6                   sistemas  4770660
# 7                  proyectos  1535389
# ..                       ...      ...
# ...

# %%
is_Alejandro = df2['nombre']=='Alejandro'
[i for i in is_Alejandro.index if is_Alejandro[i]] #list comprehension
# Out:
# [46, 73, 103, 165, 230, 243, 252, 299, 303, 378, 380, 394, 441, 534, 538, 607]

# %%
#quiero quitar lo renglones donde el nombre es 'Alejandro'
df3 = df2.drop([i for i in is_Alejandro.index if is_Alejandro[i]])

# %%
df3[df3['nombre']== 'Alejandro'] #tabla vacía porque borré a todos los 'Alejandro'
# Out:
# Empty DataFrame
# Columns: [nombre, es_directivo, genero, fh_ant, pct bono, area, salario]
# Index: []

# %%
#Sup queremos quitar la columna 'genero':
df2.drop('genero', axis = 1)
# Out:
#        nombre  es_directivo     fh_ant   pct bono                     area  \
# 0         Ana         False 1997-04-24   7.719971                 sistemas
# 1      Mónica         False 2012-06-15  14.231140    corporate investments
# 2         Ana         False 1985-12-10  10.035779                  compras
# 3    Bernardo         False 2017-11-26   8.657518                  riesgos
# 4       Laura          True 2001-03-16  12.073975  valoración y desarrollo
# ..        ...           ...        ...        ...                      ...
# 617     Edith         False 1981-05-30  10.681927          mesa de control
# 618      Olga          True 2002-04-03   9.133581    corporate investments
# 619  Jerónimo         False 2011-05-09  14.143523                staff red
# 620     Areli          True 2015-02-21   6.100000            reclutamiento
# 621      Beto          True 2017-03-15  10.000000                 staff DG
#
#      salario
# 0    2133821
# 1     339196
# 2    1886316
# ...

# %%
df2.drop('genero', axis = 'columns') #equivalente al anterior
# Out:
#        nombre  es_directivo     fh_ant   pct bono                     area  \
# 0         Ana         False 1997-04-24   7.719971                 sistemas
# 1      Mónica         False 2012-06-15  14.231140    corporate investments
# 2         Ana         False 1985-12-10  10.035779                  compras
# 3    Bernardo         False 2017-11-26   8.657518                  riesgos
# 4       Laura          True 2001-03-16  12.073975  valoración y desarrollo
# ..        ...           ...        ...        ...                      ...
# 617     Edith         False 1981-05-30  10.681927          mesa de control
# 618      Olga          True 2002-04-03   9.133581    corporate investments
# 619  Jerónimo         False 2011-05-09  14.143523                staff red
# 620     Areli          True 2015-02-21   6.100000            reclutamiento
# 621      Beto          True 2017-03-15  10.000000                 staff DG
#
#      salario
# 0    2133821
# 1     339196
# 2    1886316
# ...

# %%
df2.drop(['genero', 'salario'], axis=1)
# Out:
#        nombre  es_directivo     fh_ant   pct bono                     area
# 0         Ana         False 1997-04-24   7.719971                 sistemas
# 1      Mónica         False 2012-06-15  14.231140    corporate investments
# 2         Ana         False 1985-12-10  10.035779                  compras
# 3    Bernardo         False 2017-11-26   8.657518                  riesgos
# 4       Laura          True 2001-03-16  12.073975  valoración y desarrollo
# ..        ...           ...        ...        ...                      ...
# 617     Edith         False 1981-05-30  10.681927          mesa de control
# 618      Olga          True 2002-04-03   9.133581    corporate investments
# 619  Jerónimo         False 2011-05-09  14.143523                staff red
# 620     Areli          True 2015-02-21   6.100000            reclutamiento
# 621      Beto          True 2017-03-15  10.000000                 staff DG
#
# [622 rows x 5 columns]

# %% [markdown]
# ## Método .query()

# %% [markdown]
# El método `query()` en pandas es una herramienta flexible para filtrar filas de DataFrame utilizando una sintaxis concisa y legible. Permite seleccionar un subconjunto de filas de un DataFrame basado en una expresión de consulta.
#
# ### ¿Para qué se utiliza `query()`?
# - **Selección de Filas Basada en Condición**: El método `query()` se utiliza para filtrar filas de DataFrame basadas en una condición especificada como una cadena de texto.
# - **Sintaxis Legible y Concisa**: Proporciona una sintaxis más legible y concisa en comparación con el índice booleano tradicional.
#
# ### Sintaxis
# La sintaxis básica del método `query()` es:
# ```python
# DataFrame.query(expr, inplace=False, **kwargs)

# %% [markdown]
# #### Ojo: Los nombres de las variables necesitan NO TENER ESPACIOS.

# %%
df = pd.read_csv('empleados_3.csv', parse_dates = ['fh_ant'])
df.head()
# Out:
#      nombre  es_directivo genero     fh_ant   pct bono  \
# 0       Ana         False    NaN 1997-04-24   7.719971
# 1    Mónica         False      F 2012-06-15  14.231140
# 2       Ana         False      F 1985-12-10  10.035779
# 3  Bernardo         False      M 2017-11-26   8.657518
# 4     Laura          True      F 2001-03-16  12.073975
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736

# %%
df.columns = [column_name.replace(" ", "_") for column_name in df.columns]

# %%
df.columns
# Out:
# Index(['nombre', 'es_directivo', 'genero', 'fh_ant', 'pct_bono', 'area',
#        'salario'],
#       dtype='object')

# %%
#Seleccionar registros cuyo nombre sea 'Ana'
df.query("nombre == 'Ana'")
# Out:
#     nombre  es_directivo genero     fh_ant   pct_bono          area  salario
# 0      Ana         False    NaN 1997-04-24   7.719971      sistemas  2133821
# 2      Ana         False      F 1985-12-10  10.035779       compras  1886316
# 210    Ana         False      F 2014-03-04   8.858033  red comecial  2087614
# 584    Ana         False      F 2014-12-25   9.866410  red comecial  1804116

# %%
#nombre Ana y salario mayor a 2M
df.query("nombre == 'Ana' & salario > 2000000")
# Out:
#     nombre  es_directivo genero     fh_ant  pct_bono          area  salario
# 0      Ana         False    NaN 1997-04-24  7.719971      sistemas  2133821
# 210    Ana         False      F 2014-03-04  8.858033  red comecial  2087614

# %%
#Registros que sean 'Ana' o del área de compras
df.query("nombre == 'Ana' | area== 'compras'")
# Out:
#          nombre  es_directivo genero     fh_ant   pct_bono          area  \
# 0           Ana         False    NaN 1997-04-24   7.719971      sistemas
# 2           Ana         False      F 1985-12-10  10.035779       compras
# 12        Naomi          True      F 2004-04-19  14.306275       compras
# 18        Clara         False    NaN 1981-07-30  14.916162       compras
# 75       Camilo         False      M 1988-02-03  15.045455       compras
# 114     Edgardo         False      M 1992-02-08  13.635245       compras
# 120       Lucía         False      F 2013-08-12  16.008906       compras
# 134     Melissa         False      F 2016-06-03   9.321330       compras
# 179   Constanza         False      F 1988-04-07   5.747443       compras
# 182        Luis         False      M 1987-04-29   5.070637       compras
# 195       Paola         False      F 1981-05-25  18.230904       compras
# 210         Ana         False      F 2014-03-04   8.858033  red comecial
# ...

# %%
df.salario.describe()
# Out:
# count    6.220000e+02
# mean     2.086748e+06
# std      1.148860e+06
# min      1.032960e+05
# 25%      1.127671e+06
# 50%      2.073352e+06
# 75%      3.016213e+06
# max      4.790805e+06
# Name: salario, dtype: float64

# %%
df['salario'].describe()
# Out:
# count    6.220000e+02
# mean     2.086748e+06
# std      1.148860e+06
# min      1.032960e+05
# 25%      1.127671e+06
# 50%      2.073352e+06
# 75%      3.016213e+06
# max      4.790805e+06
# Name: salario, dtype: float64

# %%
df.query("nombre == 'Alejandro'")
# Out:
#         nombre  es_directivo genero     fh_ant   pct_bono  \
# 46   Alejandro         False      M 1989-10-08   3.820054
# 73   Alejandro         False      M 2021-05-03  13.814441
# 103  Alejandro         False      M 2021-08-03  16.484712
# 165  Alejandro         False      M 2012-05-06  11.318471
# 230  Alejandro          True      M 2018-01-02  15.927598
# 243  Alejandro         False      M 1997-08-25  16.279330
# 252  Alejandro         False      M 1998-05-21  14.050435
# 299  Alejandro          True      M 2013-04-04   6.259606
# 303  Alejandro         False      M 1980-12-06   5.486558
# 378  Alejandro         False      M 1995-10-16  15.964033
# 380  Alejandro         False      M 2014-05-11  11.549706
# 394  Alejandro         False      M 1988-06-22   9.925758
# 441  Alejandro         False      M 2003-11-13  19.050541
# 534  Alejandro          True      M 2010-08-18   6.700113
# 538  Alejandro         False      M 2017-08-08  19.103649
# ...

# %%
#Quiero los de nombre Alejandro Y cuyo salario sea mayor a la medio (promedio)
df.query("nombre == 'Alejandro' & salario > @df.salario.mean()")
# Out:
#         nombre  es_directivo genero     fh_ant   pct_bono  \
# 46   Alejandro         False      M 1989-10-08   3.820054
# 230  Alejandro          True      M 2018-01-02  15.927598
# 252  Alejandro         False      M 1998-05-21  14.050435
# 299  Alejandro          True      M 2013-04-04   6.259606
# 303  Alejandro         False      M 1980-12-06   5.486558
# 380  Alejandro         False      M 2014-05-11  11.549706
# 534  Alejandro          True      M 2010-08-18   6.700113
#
#                       area  salario
# 46                 riesgos  2893738
# 230               staff DG  3597981
# 252  corporate investments  3335073
# 299          reclutamiento  3141851
# 303       asset management  2875476
# 380               Finanzas  2978134
# 534               staff DG  2474039

# %%
sp = df.salario.mean()

# %%
#f-string: string interpolation
df.query(f"nombre == 'Alejandro' & salario > {sp}")
# Out:
#         nombre  es_directivo genero     fh_ant   pct_bono  \
# 46   Alejandro         False      M 1989-10-08   3.820054
# 230  Alejandro          True      M 2018-01-02  15.927598
# 252  Alejandro         False      M 1998-05-21  14.050435
# 299  Alejandro          True      M 2013-04-04   6.259606
# 303  Alejandro         False      M 1980-12-06   5.486558
# 380  Alejandro         False      M 2014-05-11  11.549706
# 534  Alejandro          True      M 2010-08-18   6.700113
#
#                       area  salario
# 46                 riesgos  2893738
# 230               staff DG  3597981
# 252  corporate investments  3335073
# 299          reclutamiento  3141851
# 303       asset management  2875476
# 380               Finanzas  2978134
# 534               staff DG  2474039

# %%
umbral = 1500000
df.query(f"nombre=='Alejandro' & salario > {umbral}")
# Out:
#         nombre  es_directivo genero     fh_ant   pct_bono  \
# 46   Alejandro         False      M 1989-10-08   3.820054
# 165  Alejandro         False      M 2012-05-06  11.318471
# 230  Alejandro          True      M 2018-01-02  15.927598
# 252  Alejandro         False      M 1998-05-21  14.050435
# 299  Alejandro          True      M 2013-04-04   6.259606
# 303  Alejandro         False      M 1980-12-06   5.486558
# 380  Alejandro         False      M 2014-05-11  11.549706
# 394  Alejandro         False      M 1988-06-22   9.925758
# 534  Alejandro          True      M 2010-08-18   6.700113
#
#                       area  salario
# 46                 riesgos  2893738
# 165              marketing  2026505
# 230               staff DG  3597981
# 252  corporate investments  3335073
# 299          reclutamiento  3141851
# 303       asset management  2875476
# 380               Finanzas  2978134
# 394           Contabilidad  1963149
# 534               staff DG  2474039

# %% [markdown]
# ## Groupby object

# %% [markdown]
# 1. Se crean grupos basados en valores comunes de ciertas columnas
# 2. Ideal para agrupar columnas que tienen valores repetidos.

# %%
df.head()
# Out:
#      nombre  es_directivo genero     fh_ant   pct_bono  \
# 0       Ana         False    NaN 1997-04-24   7.719971
# 1    Mónica         False      F 2012-06-15  14.231140
# 2       Ana         False      F 1985-12-10  10.035779
# 3  Bernardo         False      M 2017-11-26   8.657518
# 4     Laura          True      F 2001-03-16  12.073975
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736

# %%
df['area'].value_counts()
# Out:
# area
# staff DG                   33
# Finanzas                   32
# mesa de control            32
# operaciones                30
# cobranza                   29
# sistemas                   28
# reclutamiento              28
# riesgos                    28
# asset management           26
# valoración y desarrollo    26
# corporate investments      25
# crédito consumo            24
# Dllo de negocio            24
# compras                    23
# tecnología                 23
# ventas                     22
# red comecial               22
# proyectos                  20
# Contabilidad               19
# staff red                  18
# beneficios                 18
# marketing                  18
# inteligencia comercial     16
# data                       15
# banca digital              14
# Name: count, dtype: int64

# %%
areas = df.groupby('area') #este es un groupby object
#el argumento es un string o una lista de strings

# %%
type(areas)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
len(areas)
# Out:
# 25

# %%
df['area'].value_counts().size #tengo 25 áreas diferentes
# Out:
# 25

# %%
df.area.unique()
# Out:
# array(['sistemas', 'corporate investments', 'compras', 'riesgos',
#        'valoración y desarrollo', 'staff DG', 'proyectos', 'staff red',
#        'ventas', 'Contabilidad', 'reclutamiento', 'tecnología',
#        'inteligencia comercial', nan, 'beneficios', 'cobranza',
#        'crédito consumo', 'marketing', 'Finanzas', 'Dllo de negocio',
#        'operaciones', 'banca digital', 'asset management',
#        'mesa de control', 'red comecial', 'data'], dtype=object)

# %%
#Recordar: en areas guardé el GroupBy object
areas.size() #quiero que me des el tamaño de cada área
# Out:
# area
# Contabilidad               19
# Dllo de negocio            24
# Finanzas                   32
# asset management           26
# banca digital              14
# beneficios                 18
# cobranza                   29
# compras                    23
# corporate investments      25
# crédito consumo            24
# data                       15
# inteligencia comercial     16
# marketing                  18
# mesa de control            32
# operaciones                30
# proyectos                  20
# reclutamiento              28
# red comecial               22
# riesgos                    28
# sistemas                   28
# staff DG                   33
# staff red                  18
# tecnología                 23
# valoración y desarrollo    26
# ventas                     22
# dtype: int64

# %% [markdown]
# ### Métodos para groupby

# %%
areas.first() #da el PRIMER REGISTRO dentro de cada grupo de area (dentro de cada área)
# Out:
#                              nombre  es_directivo genero     fh_ant  \
# area
# Contabilidad                William          True      M 2014-05-20
# Dllo de negocio          Alessandra         False      F 1993-02-04
# Finanzas                      Josue         False      M 2014-03-04
# asset management           Victoria         False      F 2017-11-19
# banca digital                 Erika         False      F 2022-01-10
# beneficios                   Miguel         False      M 1999-01-16
# cobranza                    Mariana         False      F 1988-06-13
# compras                         Ana         False      F 1985-12-10
# corporate investments        Mónica         False      F 2012-06-15
# crédito consumo             Natasha         False      F 2023-08-03
# data                          Edith         False      F 1996-02-05
# inteligencia comercial        Clara         False      F 2009-09-04
# marketing                     Elena         False      F 1997-06-29
# ...

# %%
df.head()
# Out:
#      nombre  es_directivo genero     fh_ant   pct_bono  \
# 0       Ana         False    NaN 1997-04-24   7.719971
# 1    Mónica         False      F 2012-06-15  14.231140
# 2       Ana         False      F 1985-12-10  10.035779
# 3  Bernardo         False      M 2017-11-26   8.657518
# 4     Laura          True      F 2001-03-16  12.073975
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736

# %%
areas.last() #nos da la última fila de cada grupo de areas
# Out:
#                              nombre  es_directivo genero     fh_ant  \
# area
# Contabilidad                  Erika         False      F 1982-07-21
# Dllo de negocio              Camilo         False      M 1989-05-03
# Finanzas                   Jerónimo         False      M 1991-02-24
# asset management              Erika         False      F 1985-12-21
# banca digital                 Paula         False      F 1982-08-20
# beneficios                   Sandra         False      F 1983-10-06
# cobranza                    Natalia         False      F 1985-02-14
# compras                     Natasha         False      F 1986-09-22
# corporate investments          Olga          True      F 2002-04-03
# crédito consumo                Luis         False      M 2003-04-27
# data                          Pablo          True      M 1995-05-31
# inteligencia comercial      Melissa          True      F 2014-09-04
# marketing                Montserrat         False      F 2007-12-20
# ...

# %%
df.tail()
# Out:
#        nombre  es_directivo genero     fh_ant   pct_bono  \
# 617     Edith         False      F 1981-05-30  10.681927
# 618      Olga          True      F 2002-04-03   9.133581
# 619  Jerónimo         False      M 2011-05-09  14.143523
# 620     Areli          True      F 2015-02-21   6.100000
# 621      Beto          True      F 2017-03-15  10.000000
#
#                       area  salario
# 617        mesa de control  2966810
# 618  corporate investments   997318
# 619              staff red  3218007
# 620          reclutamiento  1800000
# 621               staff DG   780000

# %%
areas.groups['Contabilidad']
# Out:
# Index([ 11,  37,  38,  81, 107, 121, 139, 152, 175, 186, 265, 292, 307, 378,
#        394, 409, 511, 543, 583],
#       dtype='int64')

# %%
#un atributo del objeto groupby --> atributo groups
areas.groups
#devuelve un dictionario, donde las llaves (keys) representan cada únicao valor de área y los valores la lista con los índice del DF
#ORIGINAL
# Out:
# {'Contabilidad': [11, 37, 38, 81, 107, 121, 139, 152, 175, 186, 265, 292, 307, 378, 394, 409, 511, 543, 583], 'Dllo de negocio': [27, 64, 79, 83, 89, 189, 194, 205, 209, 268, 294, 320, 321, 326, 348, 352, 370, 390, 417, 419, 447, 468, 500, 501], 'Finanzas': [26, 50, 68, 91, 92, 100, 105, 132, 171, 181, 232, 238, 261, 313, 317, 331, 361, 380, 416, 433, 438, 463, 475, 476, 483, 502, 504, 510, 528, 532, 560, 603], 'asset management': [45, 47, 59, 108, 133, 138, 145, 154, 174, 217, 224, 283, 303, 322, 347, 364, 382, 383, 392, 399, 403, 442, 455, 471, 506, 507], 'banca digital': [41, 95, 158, 251, 297, 306, 330, 336, 369, 418, 429, 457, 497, 513], 'beneficios': [21, 44, 111, 116, 125, 140, 172, 198, 235, 255, 266, 367, 393, 396, 425, 470, 512, 586], 'cobranza': [22, 35, 73, 142, 218, 227, 228, 239, 277, 278, 279, 286, 300, 319, 377, 387, 388, 404, 412, 428, 472, 484, 498, 517, 529, 541, 590, 591, 604], 'compras': [2, 12, 18, 75, 114, 120, 134, 179, 182, 195, 215, 237, 258, 263, 350, 366, 
# ...

# %%
df.iloc[[11, 37, 38, 81, 107, 121, 139]]
# Out:
#           nombre  es_directivo genero     fh_ant   pct_bono          area  \
# 11       William          True      M 2014-05-20   9.797466  Contabilidad
# 37         Renée         False      F 1995-05-27  13.292887  Contabilidad
# 38     Constanza         False      F 2002-11-05  13.950552  Contabilidad
# 81       Mariana         False      F 2012-01-21  17.059922  Contabilidad
# 107        Josue          True      M 1980-11-05   9.636886  Contabilidad
# 121         René         False      M 2013-04-19  13.694903  Contabilidad
# 139  Laura Elena          True      F 2003-05-21  14.544775  Contabilidad
#
#      salario
# 11   2094868
# 37   3771104
# 38    830384
# 81   1786107
# 107  1126813
# 121   166827
# 139   335480

# %%
df.iloc[[26, 50, 68, 91, 92]]
# Out:
#         nombre  es_directivo genero     fh_ant   pct_bono      area  salario
# 26       Josue         False      M 2014-03-04  16.528684  Finanzas  2050761
# 50     Melissa         False      F 1995-11-12   3.062218  Finanzas  1526159
# 68  Alessandro         False      M 1982-06-17   6.664956  Finanzas  2848274
# 91     Mariana         False      F 1993-01-01   4.448793  Finanzas  1144645
# 92    Victoria         False      F 1994-09-13  14.126246  Finanzas  3841205

# %%
df.head()
# Out:
#      nombre  es_directivo genero     fh_ant   pct_bono  \
# 0       Ana         False    NaN 1997-04-24   7.719971
# 1    Mónica         False      F 2012-06-15  14.231140
# 2       Ana         False      F 1985-12-10  10.035779
# 3  Bernardo         False      M 2017-11-26   8.657518
# 4     Laura          True      F 2001-03-16  12.073975
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736

# %%
areas.sum(numeric_only=True)
# Out:
#                          es_directivo    pct_bono   salario
# area
# Contabilidad                        4  222.144297  32901364
# Dllo de negocio                     3  207.690651  47537085
# Finanzas                            7  367.619063  71633043
# asset management                    3  277.364052  58392542
# banca digital                       1  163.440306  27550513
# beneficios                          1  216.059923  35892507
# cobranza                            3  288.930443  44955157
# compras                             3  252.345900  48099497
# corporate investments               3  274.652833  48107693
# crédito consumo                     2  258.915304  49803194
# data                                3  140.606647  35265234
# inteligencia comercial              1  164.473783  39778728
# marketing                           3  230.739868  31582570
# mesa de control                     7  398.119589  71339342
# operaciones                         4  369.040194  58288575
# ...

# %%
#Si quiero agrupar por más de una variable --> le paso una lista:
df.groupby(['area', 'genero']).sum(numeric_only = True)
# Out:
#                                 es_directivo    pct_bono   salario
# area                    genero
# Contabilidad            F                  1  116.662524  19273236
#                         M                  3  105.481773  13628128
# Dllo de negocio         F                  3  133.242466  32629771
#                         M                  0   62.607254  11428006
# Finanzas                F                  2  162.447180  24940102
#                         M                  4  191.013942  42450995
# asset management        F                  3  151.575236  34134070
#                         M                  0  125.788816  24258472
# banca digital           F                  1  117.564338  21467268
#                         M                  0   45.875968   6083245
# beneficios              F                  1  106.644274  18495180
#                         M                  0   96.856707  17278950
# cobranza                F                  3  170.507209  26818448
# ...

# %%
areas[['salario', 'pct_bono']].max()
# Out:
#                          salario   pct_bono
# area
# Contabilidad             3771104  19.353260
# Dllo de negocio          3718942  19.702941
# Finanzas                 4545178  19.463156
# asset management         4185584  18.962970
# banca digital            3749949  19.959468
# beneficios               3814639  19.687791
# cobranza                 3693547  18.686733
# compras                  4737387  19.526680
# corporate investments    3813605  18.539206
# crédito consumo          3899030  19.315799
# data                     4525075  19.878147
# inteligencia comercial   4790805  19.958210
# marketing                3895460  19.384532
# mesa de control          4527912  19.937473
# operaciones              4740038  19.643457
# proyectos                4568139  19.025592
# reclutamiento            3894747  19.937400
# red comecial             3815872  19.540743
# riesgos                  4647093  19.336531
# sistemas                 4770660  19.080166
# ...

# %%
areas[['salario', 'pct_bono']].mean()
# Out:
#                               salario   pct_bono
# area
# Contabilidad             1.731651e+06  11.691805
# Dllo de negocio          1.980712e+06   8.653777
# Finanzas                 2.238533e+06  11.488096
# asset management         2.245867e+06  10.667848
# banca digital            1.967894e+06  11.674308
# beneficios               1.994028e+06  12.003329
# cobranza                 1.550178e+06   9.963119
# compras                  2.091282e+06  10.971561
# corporate investments    1.924308e+06  10.986113
# crédito consumo          2.075133e+06  10.788138
# data                     2.351016e+06   9.373776
# inteligencia comercial   2.486170e+06  10.279611
# marketing                1.754587e+06  12.818882
# mesa de control          2.229354e+06  12.441237
# operaciones              1.942952e+06  12.301340
# proyectos                2.202118e+06  10.132154
# reclutamiento            2.198586e+06  12.201871
# red comecial             1.996037e+06  11.976756
# ...

# %%
#fin clase 27 jun 2024
