# %%
import pandas as pd, numpy as np

# %%
pd.options.display.float_format = '{:.1f}'.format

# %%
emp = pd.read_csv('empleados_2.csv')

dict = {'nombre': ['Areli', 'Beto'], 'es_directivo': ['True', 'False'], 'genero': ['F', 'M'],
       'fh_ant':['2015-02-21', '2017-03-15'], 'pct bono': [6.1, 10], 'area':['reclutamiento', 'staff DG'],
       'salario': [1800000, 780000]}
aux = pd.DataFrame(dict)

emp = pd.concat([emp, aux], ignore_index=True)
emp.head()
# Out:
#      nombre es_directivo genero      fh_ant  pct bono  \
# 0       Ana        False    NaN  1997-04-24       7.7
# 1    Mónica        False      F  2012-06-15      14.2
# 2       Ana        False      M  1985-12-10      10.0
# 3  Bernardo        False      M  2017-11-26       8.7
# 4     Laura         True      F  2001-03-16      12.1
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736

# %%
emp.dtypes
# Out:
# nombre           object
# es_directivo     object
# genero           object
# fh_ant           object
# pct bono        float64
# area             object
# salario           int64
# dtype: object

# %%
#convertir fh_ant, es_directivo a tipo fecha y booleana, respectivamente
emp['fh_ant'] = pd.to_datetime(emp['fh_ant'])
emp['es_directivo'] = emp['es_directivo'].astype('bool')
emp.dtypes
# Out:
# nombre                  object
# es_directivo              bool
# genero                  object
# fh_ant          datetime64[ns]
# pct bono               float64
# area                    object
# salario                  int64
# dtype: object

# %% [markdown]
# ### Filtrar un DF según ciertos criterios

# %%
emp.head(10)
# Out:
#        nombre  es_directivo genero     fh_ant  pct bono  \
# 0         Ana         False    NaN 1997-04-24       7.7
# 1      Mónica         False      F 2012-06-15      14.2
# 2         Ana         False      M 1985-12-10      10.0
# 3    Bernardo         False      M 2017-11-26       8.7
# 4       Laura          True      F 2001-03-16      12.1
# 5      Daniel          True      M 2013-12-20      19.6
# 6        René          True      M 2002-04-12       9.4
# 7     Ignacio         False      M 1987-09-11      17.2
# 8  Alessandra         False      F 1996-08-25      12.4
# 9     William          True      F 1991-03-22       6.3
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736
# 5                 staff DG  4364527
# 6                 sistemas  4770660
# 7                proyectos  1535389
# 8                staff red  1774160
# 9                   ventas  2242909

# %%
#queremos por ejemplo, filtrar a los hombres:
emp['genero'].isnull().sum() #contando nulos en esa columna
# Out:
# 16

# %%
es_masc = emp['genero'] == 'M'
es_masc
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 617    False
# 618    False
# 619     True
# 620    False
# 621     True
# Name: genero, Length: 622, dtype: bool

# %%
#una formar de filtrar a los hombres es:
emp[es_masc] #Sólo devuelve los renglones que cumplan la condición
# Out:
#          nombre  es_directivo genero     fh_ant  pct bono           area  \
# 2           Ana         False      M 1985-12-10      10.0        compras
# 3      Bernardo         False      M 2017-11-26       8.7        riesgos
# 5        Daniel          True      M 2013-12-20      19.6       staff DG
# 6          René          True      M 2002-04-12       9.4       sistemas
# 7       Ignacio         False      M 1987-09-11      17.2      proyectos
# ..          ...           ...    ...        ...       ...            ...
# 609  Alessandra         False      M 2014-05-07      11.2  reclutamiento
# 614    Fernanda         False      M 2020-05-31      10.6            NaN
# 616        Luis         False      M 1983-09-06      11.0    operaciones
# 619    Jerónimo         False      M 2011-05-09      14.1      staff red
# 621        Beto          True      M 2017-03-15      10.0       staff DG
#
#      salario
# 2    1886316
# 3    3232929
# 5    4364527
# 6    4770660
# 7    1535389
# ..       ...
# 609  3153088
# 614  1397733
# 616   600175
# 619  3218007
# 621   780000
#
# [298 rows x 7 columns]

# %% [markdown]
# ### ¿Cómo podemos corregir la info de genero en este caso?
# * Usaremos apply, pero ligeramente diferente y una función que definiremos

# %%
nombres_h = ['Eduardo','Luis','Alejandro','Jose','Daniel','Jerónimo','Francisco','Octavio',
           'Edgardo','Sean','Mariano','Javier','Josue','Ignacio','Esteban', 'Will','Pablo', 'Bernardo', 'Eugenio',
            'Miguel', 'Alessandro','William', 'René', 'Emilio', 'Darío', 'Juan', 'Victor', 'Camilo']

# %%
emp.head(3)
# Out:
#    nombre  es_directivo genero     fh_ant  pct bono                   area  \
# 0     Ana         False    NaN 1997-04-24       7.7               sistemas
# 1  Mónica         False      F 2012-06-15      14.2  corporate investments
# 2     Ana         False      M 1985-12-10      10.0                compras
#
#    salario
# 0  2133821
# 1   339196
# 2  1886316

# %%
#Quiero:
# Si género es nulo, dejarlo en nulo
# Si nombre es nombre masculino, quiero que género = 'M'
# Si nombre es femenino, quiero gnéro = 'F'

def func_genero(row):
    if pd.isnull(row['genero']):
        return row['genero']
    elif row['nombre'] in nombres_h:
        return 'M'
    else:
        return 'F'

# %%
emp['genero'] = emp.apply(func_genero, axis = 1) #axis = 1 es necesario para evaluar más de una columna
emp.head()
# Out:
#      nombre  es_directivo genero     fh_ant  pct bono  \
# 0       Ana         False    NaN 1997-04-24       7.7
# 1    Mónica         False      F 2012-06-15      14.2
# 2       Ana         False      F 1985-12-10      10.0
# 3  Bernardo         False      M 2017-11-26       8.7
# 4     Laura          True      F 2001-03-16      12.1
#
#                       area  salario
# 0                 sistemas  2133821
# 1    corporate investments   339196
# 2                  compras  1886316
# 3                  riesgos  3232929
# 4  valoración y desarrollo  2378736

# %%
emp.tail(20)
# Out:
#           nombre  es_directivo genero     fh_ant  pct bono  \
# 602         René         False      M 1981-11-03      11.3
# 603     Jerónimo         False      M 1991-02-24       9.9
# 604      Natalia         False      F 1985-02-14       5.3
# 605   Alessandro         False      M 1988-04-23      19.6
# 606        Darío         False      M 2002-12-05      18.5
# 607    Alejandro         False      M 2010-03-12       5.4
# 608      Natalia         False      F 2001-10-26      17.6
# 609   Alessandra         False      F 2014-05-07      11.2
# 610  Laura Elena         False      F 2007-07-31      17.2
# 611       Javier          True      M 2003-07-12      16.0
# 612     Bernardo          True      M 1983-02-26       7.8
# 613      Natasha         False      F 1986-09-22      13.6
# 614     Fernanda         False      F 2020-05-31      10.6
# 615        Laura         False      F 1988-01-17       3.0
# 616         Luis         False      M 1983-09-06      11.0
# 617        Edith         False      F 1981-05-30      10.7
# 618         Olga          True      F 2002-04-03       9.1
# 619     Jerónimo         False      M 2011-05-09      14.1
# 620        Areli          True      F 2015-02-21       6.1
# 621         Beto          True      F 2017-03-15      10.0
#
#                       area  salario
# 602        mesa de control  2943837
# 603               Finanzas  3889389
# 604               cobranza   598859
# 605                 ventas  1955600
# 606  corporate investments   657814
# 607               staff DG   441911
# 608             tecnología   893263
# 609          reclutamiento  3153088
# 610            operaciones  3120092
# 611               sistemas  1453815
# 612              proyectos  2342205
# 613                compras  2267800
# 614                    NaN  1397733
# 615               sistemas  3806832
# 616            operaciones   600175
# 617        mesa de control  2966810
# 618  corporate investments   997318
# 619              staff red  3218007
# 620          reclutamiento  1800000
# 621               staff DG   780000

# %%
import os
os.getcwd()
# Out:
# '/Users/alexiscaballero/Documents/DIPLOMADO CDD UNAM/M1G2'

# %%
#exportar nuestro archivo:
emp.to_csv('/Users/alexiscaballero/Documents/DIPLOMADO CDD UNAM/M1G2/empleados_3.csv', index=False)

# %%
es_masc = emp['genero']=='M'
emp[es_masc]   #boolean mask
# Out:
#         nombre  es_directivo genero     fh_ant  pct bono         area  salario
# 3     Bernardo         False      M 2017-11-26       8.7      riesgos  3232929
# 5       Daniel          True      M 2013-12-20      19.6     staff DG  4364527
# 6         René          True      M 2002-04-12       9.4     sistemas  4770660
# 7      Ignacio         False      M 1987-09-11      17.2    proyectos  1535389
# 9      William          True      M 1991-03-22       6.3       ventas  2242909
# ..         ...           ...    ...        ...       ...          ...      ...
# 607  Alejandro         False      M 2010-03-12       5.4     staff DG   441911
# 611     Javier          True      M 2003-07-12      16.0     sistemas  1453815
# 612   Bernardo          True      M 1983-02-26       7.8    proyectos  2342205
# 616       Luis         False      M 1983-09-06      11.0  operaciones   600175
# 619   Jerónimo         False      M 2011-05-09      14.1    staff red  3218007
#
# [276 rows x 7 columns]

# %% [markdown]
# #### Siguiendo con los filtros:

# %%
#Filtrar a las personas del área de 'resgos'
mask = emp['area']== 'riesgos'
emp[mask]
# Out:
#           nombre  es_directivo genero     fh_ant  pct bono     area  salario
# 3       Bernardo         False      M 2017-11-26       8.7  riesgos  3232929
# 16       Melissa         False      F 1993-07-26       7.4  riesgos  2100226
# 24         Paula         False      F 1990-07-11      11.1  riesgos  2043242
# 34   Laura Elena          True      F 2018-05-11      13.4  riesgos  3889795
# 46     Alejandro         False      M 1989-10-08       3.8  riesgos  2893738
# 76      Penélope         False      F 1995-06-02      15.4  riesgos   951502
# 98          Luis         False      M 2008-05-15      13.2  riesgos  3014464
# 102      William          True      M 1986-05-10       9.3  riesgos  1754000
# 129      Octavio          True      M 1989-12-25       7.5  riesgos  4647093
# 146   Montserrat         False      F 1986-10-16      13.4  riesgos   541567
# 147         René         False      M 1999-05-07      11.9  riesgos  3159858
# 169        Laura         False      F 2014-10-29      13.0  riesgos  1819234
# 185   María José         False      F 1994-03-19       4.0  riesgos  2415763
# 188         Jose         False      M 2014-11-12      16.2  riesgos   729810
# 191       Nicole         False      F 2023-05-17       6.4  riesgos  1049735
# 196   María José         False      F 1985-09-01       6.2  riesgos   796153
# 234      William         False      M 2010-05-13      12.1  riesgos   773922
# 236      Natasha         False      F 2004-02-20      11.1  riesgos   474937
# 240         René         False      M 2001-10-15      15.9  riesgos  3062514
# 275        Clara         False      F 2008-02-04       7.7  riesgos  3078789
# 371        Erika         False      F 2021-01-29       8.9  riesgos  3899189
# 459        Paula         False      F 1998-11-20      15.3  riesgos  2568645
# 485    Francisco         False      M 2020-04-17      19.3  riesgos  1503293
# 486         Olga         False      F 2003-05-30      11.8  riesgos  1904004
# 496     Fernanda         False      F 2023-04-03      15.5  riesgos  2896022
# 566        Pablo         False      M 2001-11-18      13.0  riesgos   225518
# 571  Laura Elena         False      F 1989-07-02       4.0  riesgos   830338
# 575       Victor         False      M 1991-02-27      15.3  riesgos   562184

# %%
#equivalentemente:
emp[emp['area']=='riesgos']
# Out:
#           nombre  es_directivo genero     fh_ant  pct bono     area  salario
# 3       Bernardo         False      M 2017-11-26       8.7  riesgos  3232929
# 16       Melissa         False      F 1993-07-26       7.4  riesgos  2100226
# 24         Paula         False      F 1990-07-11      11.1  riesgos  2043242
# 34   Laura Elena          True      F 2018-05-11      13.4  riesgos  3889795
# 46     Alejandro         False      M 1989-10-08       3.8  riesgos  2893738
# 76      Penélope         False      F 1995-06-02      15.4  riesgos   951502
# 98          Luis         False      M 2008-05-15      13.2  riesgos  3014464
# 102      William          True      M 1986-05-10       9.3  riesgos  1754000
# 129      Octavio          True      M 1989-12-25       7.5  riesgos  4647093
# 146   Montserrat         False      F 1986-10-16      13.4  riesgos   541567
# 147         René         False      M 1999-05-07      11.9  riesgos  3159858
# 169        Laura         False      F 2014-10-29      13.0  riesgos  1819234
# 185   María José         False      F 1994-03-19       4.0  riesgos  2415763
# 188         Jose         False      M 2014-11-12      16.2  riesgos   729810
# 191       Nicole         False      F 2023-05-17       6.4  riesgos  1049735
# 196   María José         False      F 1985-09-01       6.2  riesgos   796153
# 234      William         False      M 2010-05-13      12.1  riesgos   773922
# 236      Natasha         False      F 2004-02-20      11.1  riesgos   474937
# 240         René         False      M 2001-10-15      15.9  riesgos  3062514
# 275        Clara         False      F 2008-02-04       7.7  riesgos  3078789
# 371        Erika         False      F 2021-01-29       8.9  riesgos  3899189
# 459        Paula         False      F 1998-11-20      15.3  riesgos  2568645
# 485    Francisco         False      M 2020-04-17      19.3  riesgos  1503293
# 486         Olga         False      F 2003-05-30      11.8  riesgos  1904004
# 496     Fernanda         False      F 2023-04-03      15.5  riesgos  2896022
# 566        Pablo         False      M 2001-11-18      13.0  riesgos   225518
# 571  Laura Elena         False      F 1989-07-02       4.0  riesgos   830338
# 575       Victor         False      M 1991-02-27      15.3  riesgos   562184

# %%
emp.dtypes
# Out:
# nombre                  object
# es_directivo              bool
# genero                  object
# fh_ant          datetime64[ns]
# pct bono               float64
# area                    object
# salario                  int64
# dtype: object

# %%
#queremos filtrar a los empleados que son directivos:
mask = emp['es_directivo']
emp[mask]
# Out:
#        nombre  es_directivo genero     fh_ant  pct bono  \
# 4       Laura          True      F 2001-03-16      12.1
# 5      Daniel          True      M 2013-12-20      19.6
# 6        René          True      M 2002-04-12       9.4
# 9     William          True      M 1991-03-22       6.3
# 11    William          True      M 2014-05-20       9.8
# ..        ...           ...    ...        ...       ...
# 611    Javier          True      M 2003-07-12      16.0
# 612  Bernardo          True      M 1983-02-26       7.8
# 618      Olga          True      F 2002-04-03       9.1
# 620     Areli          True      F 2015-02-21       6.1
# 621      Beto          True      F 2017-03-15      10.0
#
#                         area  salario
# 4    valoración y desarrollo  2378736
# 5                   staff DG  4364527
# 6                   sistemas  4770660
# 9                     ventas  2242909
# 11              Contabilidad  2094868
# ..                       ...      ...
# 611                 sistemas  1453815
# 612                proyectos  2342205
# 618    corporate investments   997318
# 620            reclutamiento  1800000
# 621                 staff DG   780000
#
# [94 rows x 7 columns]

# %%
emp[emp['es_directivo']] #porque 'es_directivo' es boolean
# Out:
#        nombre  es_directivo genero     fh_ant  pct bono  \
# 4       Laura          True      F 2001-03-16      12.1
# 5      Daniel          True      M 2013-12-20      19.6
# 6        René          True      M 2002-04-12       9.4
# 9     William          True      M 1991-03-22       6.3
# 11    William          True      M 2014-05-20       9.8
# ..        ...           ...    ...        ...       ...
# 611    Javier          True      M 2003-07-12      16.0
# 612  Bernardo          True      M 1983-02-26       7.8
# 618      Olga          True      F 2002-04-03       9.1
# 620     Areli          True      F 2015-02-21       6.1
# 621      Beto          True      F 2017-03-15      10.0
#
#                         area  salario
# 4    valoración y desarrollo  2378736
# 5                   staff DG  4364527
# 6                   sistemas  4770660
# 9                     ventas  2242909
# 11              Contabilidad  2094868
# ..                       ...      ...
# 611                 sistemas  1453815
# 612                proyectos  2342205
# 618    corporate investments   997318
# 620            reclutamiento  1800000
# 621                 staff DG   780000
#
# [94 rows x 7 columns]

# %%
#-- fin clase 19 jun 2024
