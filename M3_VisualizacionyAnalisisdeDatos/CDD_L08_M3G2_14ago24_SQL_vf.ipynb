# %%
from pandasql import sqldf
import pandas as pd

# %%
def fsql(q):
    return sqldf(q, globals())

# %%
departments = pd.read_csv('departments.csv')
employees = pd.read_csv('upd_empl_2.csv')
regions = pd.read_csv('regions.csv')

# %%
# Sup queremos crear una variable 'estatus_pago' con base en la siguiente definición:

#salary < 90000 --> 'bajo'
# salary >= 90000 AND salary < 150000 --> 'bien pagado'
# en otro caso: 'muy bien pagado'

# --> sentencia CASE:

q="""
SELECT first_name, salary,
CASE
    WHEN salary < 90000 THEN 'BAJO'
    WHEN salary >= 90000 AND salary < 150000 THEN 'BIEN PAGADO'
    ELSE 'muy bien pagado'
END AS estatus_pago                 -- Termina con END AS nombre_de_variable
FROM employees
ORDER BY salary DESC;
"""
df = fsql(q)

# %%
df['estatus_pago'].value_counts()
# Out:
# estatus_pago
# BAJO               504
# BIEN PAGADO        375
# muy bien pagado    121
# Name: count, dtype: int64

# %% [markdown]
# #### QUEREMOS lo mismo que hace value_counts(), pero en SQL

# %%
q="""
SELECT a.estatus_pago, COUNT(*) AS conteo
FROM(
SELECT first_name, salary,
CASE
    WHEN salary < 90000 THEN 'BAJO'
    WHEN salary >= 90000 AND salary < 150000 THEN 'BIEN PAGADO'
    ELSE 'muy bien pagado'
END AS estatus_pago                 -- Termina con END AS nombre_de_variable
FROM employees
ORDER BY salary DESC) a
GROUP BY a.estatus_pago;
"""
fsql(q)
# Out:
#       estatus_pago  conteo
# 0             BAJO     504
# 1      BIEN PAGADO     375
# 2  muy bien pagado     121

# %% [markdown]
# Sup quiero transponer los datos, i.e.:
#
#     bajo      bien pagado      muy bien pagado
#     504         375                 121

# %%
q="""
SELECT SUM(CASE WHEN salary < 90000 THEN 1 ELSE 0 END) bajo,
SUM(CASE WHEN salary >= 90000 AND salary < 150000 THEN 1 ELSE 0 END) bien_pagado,
SUM(CASE WHEN salary > 150000 THEN 1 ELSE 0 END) muy_bien_pagado
FROM employees;
"""
fsql(q)
# Out:
#    bajo  bien_pagado  muy_bien_pagado
# 0   504          375              121

# %%
#quiero ahora igual que el anterior pero una columna al último con el total
q="""
SELECT a.bajo, a.bien_pagado, a.muy_bien_pagado, a.bajo + a.bien_pagado + a.muy_bien_pagado AS TOTAL
FROM
(SELECT SUM(CASE WHEN salary < 90000 THEN 1 ELSE 0 END) bajo,
SUM(CASE WHEN salary >= 90000 AND salary < 150000 THEN 1 ELSE 0 END) bien_pagado,
SUM(CASE WHEN salary > 150000 THEN 1 ELSE 0 END) muy_bien_pagado
FROM employees) a;
"""
fsql(q)
# Out:
#    bajo  bien_pagado  muy_bien_pagado  TOTAL
# 0   504          375              121   1000

# %%
employees.head(3)
# Out:
#    employee_id first_name last_name            email   hire_date department  \
# 0            1     Berrie   Manueau  berr@aol.com.mx  2006-04-20     Sports
# 1            2    Aeriell     McNee    aeri@gmail.co  2009-01-26      Tools
# 2            3     Sydney   Symonds    sydn@terra.mx  2010-05-17   Clothing
#
#   gender  salary  region_id
# 0      F  154864          4
# 1      F   56752          3
# 2      F   95313          4

# %% [markdown]
# Supongamos quiero una consulta que me de lo siguiente:
#
#     depto 1  n1
#     depto 2  n2
#     depto 3  n3
#     .
#     .
#     .
#
# pero sólo considerando los deptos "Sports", "Tools", "Clothing"

# %%
#ejercicio
q="""
SELECT department, COUNT(*) num_empleados
FROM employees
WHERE department IN ('Sports', 'Tools', 'Clothing')
GROUP BY department;
"""
fsql(q)
# Out:
#   department  num_empleados
# 0   Clothing             49
# 1     Sports             34
# 2      Tools             39

# %% [markdown]
# ## En caso de querer un Total:
#     depto 1  n1
#     depto 2  n2
#     depto 3  n3
#     .
#     Total    N

# %%
#1. Sacar los conteos por departamento (ejercicio anterior)
#2. A ese resultado le vamos a dar un nombre usando la sentencia WITH
#3. Vamos a hacer una union del resultado de 2 con una consulta adicional que tenga el Total (UNION ALL)

# %%
q="""
WITH tabla_1 AS(
    SELECT department, COUNT(*) num_empleados
    FROM employees
    WHERE department IN ('Sports', 'Tools', 'Clothing')
    GROUP BY department
)

SELECT * FROM tabla_1
UNION ALL          --   equivale a apilar las tablas

SELECT 'Total' department, SUM(num_empleados) num_empleados
FROM tabla_1;
"""
fsql(q)
# Out:
#   department  num_empleados
# 0   Clothing             49
# 1     Sports             34
# 2      Tools             39
# 3      Total            122

# %%
employees.head(3)
# Out:
#    employee_id first_name last_name            email   hire_date department  \
# 0            1     Berrie   Manueau  berr@aol.com.mx  2006-04-20     Sports
# 1            2    Aeriell     McNee    aeri@gmail.co  2009-01-26      Tools
# 2            3     Sydney   Symonds    sydn@terra.mx  2010-05-17   Clothing
#
#   gender  salary  region_id
# 0      F  154864          4
# 1      F   56752          3
# 2      F   95313          4

# %% [markdown]
# Si quiero transponer estos resultados de la siguiente forma:
#
#     Clothing     Sports    Tools
#       49           34        39

# %%
q="""
SELECT SUM(CASE WHEN department = 'Tools' THEN 1 ELSE 0 END) As num_empl_tools,
SUM(CASE WHEN department = 'Sports' THEN 1 ELSE 0 END) As num_empl_sports,
SUM(CASE WHEN department = 'Clothing' THEN 1 ELSE 0 END) As num_empl_clothing
FROM employees;
"""
fsql(q)
# Out:
#    num_empl_tools  num_empl_sports  num_empl_clothing
# 0              39               34                 49

# %%
#equivalentemente:
q="""
SELECT SUM(CASE WHEN department = 'Tools' THEN 1 ELSE 0 END) num_empl_tools,
SUM(CASE WHEN department = 'Sports' THEN 1 ELSE 0 END)  num_empl_sports,
SUM(CASE WHEN department = 'Clothing' THEN 1 ELSE 0 END) num_empl_clothing
FROM employees;
"""
fsql(q)
# Out:
#    num_empl_tools  num_empl_sports  num_empl_clothing
# 0              39               34                 49

# %%
employees.head(2)
# Out:
#    employee_id first_name last_name            email   hire_date department  \
# 0            1     Berrie   Manueau  berr@aol.com.mx  2006-04-20     Sports
# 1            2    Aeriell     McNee    aeri@gmail.co  2009-01-26      Tools
#
#   gender  salary  region_id
# 0      F  154864          4
# 1      F   56752          3

# %%
departments.head(2)
# Out:
#   department division
# 0   Clothing     Home
# 1    Grocery     Home

# %%
regions.head(8)
# Out:
#    region_id       region        country
# 0          1    Southwest  United States
# 1          2    Northeast  United States
# 2          3    Northwest  United States
# 3          4      Central           Asia
# 4          5    East Asia           Asia
# 5          6       Quebec         Canada
# 6          7  Nova Scotia         Canada

# %% [markdown]
# ## Ejercicios

# %%
#1. Quiero el promedio del salario de los empleados por departamento, con el salario redondeado a 2 decimales
q="""
SELECT department, ROUND(AVG(salary),2) AS salario_medio
FROM employees
GROUP BY department;
"""
fsql(q)
# Out:
#            department  salario_medio
# 0          Automotive      111046.16
# 1              Beauty       96487.44
# 2               Books       96497.41
# 3             Camping       97302.03
# 4   Children Clothing       87511.04
# 5            Clothing       83933.45
# 6           Computers       96064.57
# 7           Cosmetics      108381.71
# 8               Decor       92766.21
# 9       Device Repair       87480.73
# 10          First Aid       89154.53
# 11          Furniture       87373.40
# 12              Games       85684.56
# 13             Garden       85431.49
# 14            Grocery       94295.89
# 15            Jewelry       80576.10
# 16        Maintenance       76792.75
# 17             Movies       89246.39
# 18              Music       92360.97
# 19           Pharmacy       93372.13
# 20   Phones & Tablets       89688.03
# 21           Plumbing       98224.14
# 22           Security       89950.17
# 23             Sports       87832.47
# 24              Tools       83529.62
# 25               Toys      103110.02
# 26           Vitamins       90358.00

# %%
#2. Quiero la tabla de empleados ordenada de formada descendente por hire_date y que sólo se muestren los primeros 20 registros:
q="""
SELECT * FROM employees
ORDER BY hire_date DESC
LIMIT 20;
"""
fsql(q)
# Out:
#     employee_id first_name  last_name              email   hire_date  \
# 0           791      Barby    Daniell  barb@yahoo.com.mx  2016-12-26
# 1           460  Cherianne      Oxnam      cher@gmail.co  2016-12-18
# 2           272      Roxie    Revance  roxi@yahoo.com.mx  2016-12-16
# 3           380       Edik  Wardhough      edik@terra.mx  2016-12-11
# 4           491     Eloisa      Eeles     eloi@yahoo.com  2016-12-02
# 5           753   Adelaide     Gubbin    adel@excite.com  2016-12-01
# 6           876    Marlowe      Crock    marl@excite.com  2016-12-01
# 7           131      Hewet   Calafate     hewe@yahoo.com  2016-11-24
# 8           371    Malcolm    D'Costa      malc@terra.mx  2016-11-24
# 9           655      Darin      Pooke     dari@yahoo.com  2016-11-18
# 10          973       Dona     Murley   dona@hotmail.com  2016-11-09
# 11          925      Alvin   McMullen      alvi@terra.mx  2016-11-01
# 12          879        Reg    Newland    reg@hotmail.com  2016-10-28
# 13          288     Buckie  Jodrellec    buck@aol.com.mx  2016-10-10
# 14          672      Jeane   Partener       jean@aol.com  2016-10-09
# 15          894     Lebbie  Slaymaker     lebb@yahoo.com  2016-10-07
# 16          771      Berti  Randerson      bert@gmail.co  2016-10-06
# 17          696       Roma    Pfeifer       roma@aol.com  2016-10-02
# 18          712    Ernesto    Locarno      erne@gmail.co  2016-09-26
# 19          170    Linnell       Haps    linn@excite.com  2016-09-25
#
#            department gender  salary  region_id
# 0            Clothing      F  164588          6
# 1          Automotive      F  150821          6
# 2    Phones & Tablets      F   42224          2
# 3               Tools      M   88378          2
# 4            Clothing      F   39200          4
# 5                Toys      F   27578          7
# 6             Jewelry      M   66384          1
# 7    Phones & Tablets      M  113979          2
# 8              Garden      M  138493          1
# 9              Movies      M  142023          2
# 10              Decor      F   98159          1
# 11             Beauty      M   69999          3
# 12             Beauty      M   36053          3
# 13           Vitamins      M   30289          4
# 14           Pharmacy      F  136466          5
# 15            Grocery      F   57389          4
# 16  Children Clothing      M  150740          3
# 17              Tools      M  120070          1
# 18              Music      M   57633          2
# 19          Computers      F   98885          7

# %%
#3. Haz un query que devuelva a los empleados de la region 'Central':
q="""
SELECT * FROM employees
WHERE region_id IN (SELECT region_id FROM regions WHERE region="Central");
"""
fsql(q)
# Out:
#      employee_id first_name  last_name              email   hire_date  \
# 0              1     Berrie    Manueau    berr@aol.com.mx  2006-04-20
# 1              3     Sydney    Symonds      sydn@terra.mx  2010-05-17
# 2             23      Vanda    Marwick  vand@yahoo.com.mx  2014-02-06
# 3             29     Cortie  Ambrosini     cort@yahoo.com  2014-05-03
# 4             53   Alphonse      Shedd     alph@gmail.com  2014-08-17
# ..           ...        ...        ...                ...         ...
# 132          970    Barrett    Barling      barr@gmail.co  2005-10-26
# 133          975       Isis     McKinn    isis@excite.com  2010-06-18
# 134          977     Vickie       Pryn      vick@gmail.co  2012-02-24
# 135          980      Lyndy     Tooker     lynd@gmail.com  2007-01-26
# 136          991   Marquita    Seawell   marq@hotmail.com  2014-09-07
#
#      department gender  salary  region_id
# 0        Sports      F  154864          4
# 1      Clothing      F   95313          4
# 2    Automotive      F  103570          4
# 3         Games      M  133847          4
# 4     Cosmetics      M   33272          4
# ..          ...    ...     ...        ...
# 132     Grocery      M  128512          4
# 133      Movies      F  124444          4
# 134      Movies      F   33269          4
# 135   Computers      F  112796          4
# 136      Sports      F   38909          4
#
# [137 rows x 9 columns]

# %%
regions
# Out:
#    region_id       region        country
# 0          1    Southwest  United States
# 1          2    Northeast  United States
# 2          3    Northwest  United States
# 3          4      Central           Asia
# 4          5    East Asia           Asia
# 5          6       Quebec         Canada
# 6          7  Nova Scotia         Canada

# %%
#4. hAZ un query que devuelva el promedio del salario por hombres y mujeres en la region "Central":
q="""
SELECT gender, AVG(salary) FROM employees
WHERE region_id IN (SELECT region_id FROM regions WHERE region="Central")
GROUP BY gender;
"""
fsql(q)
# Out:
#   gender   AVG(salary)
# 0      F  90030.355263
# 1      M  96746.245902

# %%
#5. Quiero el conteo de hombres y mujeres:
q="""
SELECT gender, COUNT(*) AS conteo
FROM employees
GROUP BY gender;       -- COUNT(*) porque estamos contando sobre los renglones
"""
fsql(q)
# Out:
#   gender  conteo
# 0      F     501
# 1      M     499

# %%
#Si además quierom que el resultado esté ordenado de menor a mayor
q="""
SELECT gender, COUNT(*) AS conteo
FROM employees
GROUP BY gender
ORDER BY conteo;
"""
fsql(q)
# Out:
#   gender  conteo
# 0      M     499
# 1      F     501

# %%
#Equivalente a lo anterior:
q="""
SELECT gender, COUNT(*) AS conteo
FROM employees
GROUP BY 1
ORDER BY 2;
"""
fsql(q)
# Out:
#   gender  conteo
# 0      M     499
# 1      F     501

# %%
#6. Ahora quiero el conteo pero en formato:
 #           F    M
 #           n1   n2

# %%
q="""
SELECT SUM(CASE WHEN gender = 'F' THEN 1 ELSE 0 END) AS mujeres,
SUM(CASE WHEN gender = 'M' THEN 1 ELSE 0 END) AS hombres
FROM employees;
"""
fsql(q)
# Out:
#    mujeres  hombres
# 0      501      499

# %% [markdown]
# ### BETWEEN
# Sintaxis: BETWEEN x AND y

# %%
#7. Selecciona a los empleados que fueron contratados entre el 25 sep y el 9 nov de 2016:

q="""
SELECT * FROM employees
WHERE hire_date BETWEEN '2016-09-25' AND '2016-11-09'
ORDER BY hire_date DESC;
"""
fsql(q)
# Out:
#     employee_id first_name  last_name             email   hire_date  \
# 0           973       Dona     Murley  dona@hotmail.com  2016-11-09
# 1           925      Alvin   McMullen     alvi@terra.mx  2016-11-01
# 2           879        Reg    Newland   reg@hotmail.com  2016-10-28
# 3           288     Buckie  Jodrellec   buck@aol.com.mx  2016-10-10
# 4           672      Jeane   Partener      jean@aol.com  2016-10-09
# 5           894     Lebbie  Slaymaker    lebb@yahoo.com  2016-10-07
# 6           771      Berti  Randerson     bert@gmail.co  2016-10-06
# 7           696       Roma    Pfeifer      roma@aol.com  2016-10-02
# 8           712    Ernesto    Locarno     erne@gmail.co  2016-09-26
# 9           170    Linnell       Haps   linn@excite.com  2016-09-25
# 10          919    Carissa   Gabbitus  cari@hotmail.com  2016-09-25
#
#            department gender  salary  region_id
# 0               Decor      F   98159          1
# 1              Beauty      M   69999          3
# 2              Beauty      M   36053          3
# 3            Vitamins      M   30289          4
# 4            Pharmacy      F  136466          5
# 5             Grocery      F   57389          4
# 6   Children Clothing      M  150740          3
# 7               Tools      M  120070          1
# 8               Music      M   57633          2
# 9           Computers      F   98885          7
# 10              Music      F  166765          2

# %%
employees.head(3)
# Out:
#    employee_id first_name last_name            email   hire_date department  \
# 0            1     Berrie   Manueau  berr@aol.com.mx  2006-04-20     Sports
# 1            2    Aeriell     McNee    aeri@gmail.co  2009-01-26      Tools
# 2            3     Sydney   Symonds    sydn@terra.mx  2010-05-17   Clothing
#
#   gender  salary  region_id
# 0      F  154864          4
# 1      F   56752          3
# 2      F   95313          4
